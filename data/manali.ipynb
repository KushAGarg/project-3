# %%
#importing necessary libraries 
import pandas as pd
import datetime
import matplotlib.pyplot as plt

# %%
#reading in csv file into a dataframe 
df_ufo = pd.read_csv('scrubbed.csv')
df_ufo
# Out:
# /var/folders/_z/y17b_m151jb68st8bhhh9g_w0000gn/T/ipykernel_41130/3324218002.py:2: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ufo = pd.read_csv('scrubbed.csv')
#                datetime                  city state country     shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# 80331    9/9/2013 23:00                edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min)  \
# 0                   2700           45 minutes
# 1                   7200              1-2 hrs
# 2                     20           20 seconds
# 3                     20             1/2 hour
# 4                    900           15 minutes
# ...                  ...                  ...
# 80327              600.0           10 minutes
# 80328             1200.0           20 minutes
# 80329             1200.0                 hour
# 80330                5.0            5 seconds
# 80331             1020.0           17 minutes
#
#                                                 comments date posted  \
# 0      This event took place in early fall around 194...   4/27/2004
# 1      1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005
# 2      Green/Orange circular disc over Chester&#44 En...   1/21/2008
# 3      My older brother and twin sister were leaving ...   1/17/2004
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004
# ...                                                  ...         ...
# 80327  Round from the distance/slowly changing colors...   9/30/2013
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...   9/30/2013
# 80329                                       Napa UFO&#44   9/30/2013
# 80330  Saw a five gold lit cicular craft moving fastl...   9/30/2013
# 80331  2 witnesses 2  miles apart&#44 Red &amp; White...   9/30/2013
#
#          latitude  longitude
# 0      29.8830556  -97.941111
# 1        29.38421  -98.581082
# 2            53.2   -2.916667
# 3      28.9783333  -96.645833
# 4      21.4180556 -157.803611
# ...           ...         ...
# 80327   36.165833  -86.784444
# 80328   43.613611 -116.202500
# 80329   38.297222 -122.284444
# 80330   38.901111  -77.265556
# 80331   35.652778  -97.477778
#
# [80332 rows x 11 columns]

# %%
#storing only the data from the USA into a new dataframe 
df_usa=df_ufo[df_ufo["country"]=="us"]
df_usa
# Out:
#                datetime        city state country     shape  \
# 0      10/10/1949 20:30  san marcos    tx      us  cylinder
# 3      10/10/1956 21:00        edna    tx      us    circle
# 4      10/10/1960 20:00     kaneohe    hi      us     light
# 5      10/10/1961 19:00     bristol    tn      us    sphere
# 7      10/10/1965 23:45     norwalk    ct      us      disk
# ...                 ...         ...   ...     ...       ...
# 80327    9/9/2013 21:15   nashville    tn      us     light
# 80328    9/9/2013 22:00       boise    id      us    circle
# 80329    9/9/2013 22:00        napa    ca      us     other
# 80330    9/9/2013 22:20      vienna    va      us    circle
# 80331    9/9/2013 23:00      edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min)  \
# 0                   2700           45 minutes
# 3                     20             1/2 hour
# 4                    900           15 minutes
# 5                    300            5 minutes
# 7                   1200           20 minutes
# ...                  ...                  ...
# 80327              600.0           10 minutes
# 80328             1200.0           20 minutes
# 80329             1200.0                 hour
# 80330                5.0            5 seconds
# 80331             1020.0           17 minutes
#
#                                                 comments date posted  \
# 0      This event took place in early fall around 194...   4/27/2004
# 3      My older brother and twin sister were leaving ...   1/17/2004
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004
# 5      My father is now 89 my brother 52 the girl wit...   4/27/2007
# 7      A bright orange color changing to reddish colo...   10/2/1999
# ...                                                  ...         ...
# 80327  Round from the distance/slowly changing colors...   9/30/2013
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...   9/30/2013
# 80329                                       Napa UFO&#44   9/30/2013
# 80330  Saw a five gold lit cicular craft moving fastl...   9/30/2013
# 80331  2 witnesses 2  miles apart&#44 Red &amp; White...   9/30/2013
#
#          latitude  longitude
# 0      29.8830556  -97.941111
# 3      28.9783333  -96.645833
# 4      21.4180556 -157.803611
# 5      36.5950000  -82.188889
# 7      41.1175000  -73.408333
# ...           ...         ...
# 80327   36.165833  -86.784444
# 80328   43.613611 -116.202500
# 80329   38.297222 -122.284444
# 80330   38.901111  -77.265556
# 80331   35.652778  -97.477778
#
# [65114 rows x 11 columns]

# %%
#dropping the "comments" and "duration" columns
df_scrubbed_usa=df_usa.drop("comments",axis=1)
df_scrubbed_usa=df_scrubbed_usa.drop("duration (hours/min)",axis=1)
df_scrubbed_usa
# Out:
#                datetime        city state country     shape  \
# 0      10/10/1949 20:30  san marcos    tx      us  cylinder
# 3      10/10/1956 21:00        edna    tx      us    circle
# 4      10/10/1960 20:00     kaneohe    hi      us     light
# 5      10/10/1961 19:00     bristol    tn      us    sphere
# 7      10/10/1965 23:45     norwalk    ct      us      disk
# ...                 ...         ...   ...     ...       ...
# 80327    9/9/2013 21:15   nashville    tn      us     light
# 80328    9/9/2013 22:00       boise    id      us    circle
# 80329    9/9/2013 22:00        napa    ca      us     other
# 80330    9/9/2013 22:20      vienna    va      us    circle
# 80331    9/9/2013 23:00      edmond    ok      us     cigar
#
#       duration (seconds) date posted    latitude  longitude
# 0                   2700   4/27/2004  29.8830556  -97.941111
# 3                     20   1/17/2004  28.9783333  -96.645833
# 4                    900   1/22/2004  21.4180556 -157.803611
# 5                    300   4/27/2007  36.5950000  -82.188889
# 7                   1200   10/2/1999  41.1175000  -73.408333
# ...                  ...         ...         ...         ...
# 80327              600.0   9/30/2013   36.165833  -86.784444
# 80328             1200.0   9/30/2013   43.613611 -116.202500
# 80329             1200.0   9/30/2013   38.297222 -122.284444
# 80330                5.0   9/30/2013   38.901111  -77.265556
# 80331             1020.0   9/30/2013   35.652778  -97.477778
#
# [65114 rows x 9 columns]

# %%
df_scrubbed_usa = df_scrubbed_usa.rename(columns={'longitude ':'longitude'})

# %%
# changing some rows in duration(seconds) so they are not strings
df_scrubbed_usa.at[27822,"duration (seconds)"]=2
df_scrubbed_usa.at[35692,"duration (seconds)"]=8

# changing some rows in datetime to make it in the right format to convert
df_scrubbed_usa.at[388,"datetime"]="10/12/2006 00:00"
df_scrubbed_usa.at[962,"datetime"]="10/2/2012 00:00"
df_scrubbed_usa.at[1221,"datetime"]="10/13/2012 00:00"
df_scrubbed_usa.at[1222,"datetime"]="10/13/2012 00:00"
df_scrubbed_usa.at[1317,"datetime"]="10/14/2004 00:00"
df_scrubbed_usa.at[1359,"datetime"]="10/14/2007 00:00"
df_scrubbed_usa.at[1445,"datetime"]="10/14/2012 00:00"
df_scrubbed_usa.at[1663,"datetime"]="10/15/2011 00:00"

# %%
#changing all 24:00 to 23:59 so it is in the proper format to change into datetime type
df_scrubbed_usa["datetime"]=df_scrubbed_usa["datetime"].replace("24:00","23:59", regex=True)

# %%
#changing the data types of the columns to make easier when grouping
df_scrubbed_usa["latitude"]=df_scrubbed_usa["latitude"].astype("float64")
df_scrubbed_usa["duration (seconds)"]=df_scrubbed_usa["duration (seconds)"].astype("float64")
df_scrubbed_usa["date posted"]=df_scrubbed_usa["date posted"].astype("datetime64")
df_scrubbed_usa["datetime"]=df_scrubbed_usa["datetime"].astype("datetime64")

# %%
#creating an ID column to help with referencing
df_scrubbed_usa
ids = range(1, len(df_scrubbed_usa) + 1)
df_scrubbed_usa['ID'] = ids
df_scrubbed_usa = df_scrubbed_usa[['ID', 'datetime', 'city', 'state', 'country',\
                                  'shape', 'duration (seconds)', 'latitude', \
                                  'longitude', 'date posted']]
df_scrubbed_usa.head()
# Out:
#    ID            datetime        city state country     shape  \
# 0   1 1949-10-10 20:30:00  san marcos    tx      us  cylinder
# 3   2 1956-10-10 21:00:00        edna    tx      us    circle
# 4   3 1960-10-10 20:00:00     kaneohe    hi      us     light
# 5   4 1961-10-10 19:00:00     bristol    tn      us    sphere
# 7   5 1965-10-10 23:45:00     norwalk    ct      us      disk
#
#    duration (seconds)   latitude   longitude date posted
# 0              2700.0  29.883056  -97.941111  2004-04-27
# 3                20.0  28.978333  -96.645833  2004-01-17
# 4               900.0  21.418056 -157.803611  2004-01-22
# 5               300.0  36.595000  -82.188889  2007-04-27
# 7              1200.0  41.117500  -73.408333  1999-10-02

# %% [markdown]
# # Creating new dataframes

# %% [markdown]
# Now that the data has been cleaned, it is time to create different grouped dataframes to create our graphs and visuals

# %%
ufo=df_scrubbed_usa.groupby(["datetime"])["state"].max()

ufo_state=pd.DataFrame({"State": ufo,})
ufo_state
# Out:
#                     State
# datetime
# 1910-01-01 23:59:00    mo
# 1910-06-01 15:00:00    tx
# 1920-06-11 21:00:00    in
# 1925-12-28 18:00:00    il
# 1929-07-05 14:00:00    or
# ...                   ...
# 2014-05-07 20:30:00    fl
# 2014-05-07 21:00:00    al
# 2014-05-07 21:10:00    ct
# 2014-05-07 21:20:00    mo
# 2014-05-08 00:00:00    tn
#
# [57069 rows x 1 columns]

# %%
ufo2=df_scrubbed_usa.groupby(["shape"])["datetime"].max()

ufo_shape=pd.DataFrame({"time": ufo2,})
ufo_shape
# Out:
#                          time
# shape
# changed   1996-06-24 00:30:00
# changing  2014-05-05 19:30:00
# chevron   2014-04-27 23:00:00
# cigar     2014-05-01 23:05:00
# circle    2014-05-07 21:00:00
# cone      2014-04-09 22:35:00
# crescent  1997-03-22 22:30:00
# cross     2014-05-02 20:30:00
# cylinder  2014-05-06 20:35:00
# delta     1997-10-10 16:00:00
# diamond   2014-05-06 21:30:00
# disk      2014-05-07 15:00:00
# egg       2014-05-03 04:10:00
# fireball  2014-05-07 21:20:00
# flare     1997-11-30 18:00:00
# flash     2014-05-02 22:30:00
# formation 2014-05-03 23:30:00
# hexagon   1997-12-16 19:55:00
# light     2014-05-06 21:00:00
# other     2014-05-06 22:15:00
# oval      2014-05-07 17:30:00
# pyramid   1997-01-11 05:00:00
# rectangle 2014-05-08 00:00:00
# round     1996-11-16 23:23:00
# sphere    2014-05-06 23:00:00
# teardrop  2014-04-29 02:15:00
# triangle  2014-05-05 22:45:00
# unknown   2014-05-07 21:10:00

# %%
ufo3=df_scrubbed_usa.groupby(["shape"]).size().reset_index(name='count')
ufo_shape_count = ufo3.sort_values(by='count', ascending=False)
ufo_shape_count.head(10)
# Out:
#         shape  count
# 18      light  13473
# 26   triangle   6549
# 4      circle   6118
# 13   fireball   5148
# 27    unknown   4567
# 19      other   4466
# 24     sphere   4347
# 11       disk   4121
# 20       oval   3032
# 16  formation   1990

# %%
# plot_pandas = ufo_shape_count.plot.bar(color='blue')  
# plt.xlabel("Shape")
# plt.ylabel("Count")
# plt.title("How many times each shape was seen")
# plt.show()

# %%
ufo4=df_scrubbed_usa.groupby(["city"]).size().reset_index(name='count')
ufo_city_count = ufo4.sort_values(by='count', ascending=False)
ufo_city_count.head(15)
# Out:
#               city  count
# 9110       seattle    524
# 7877       phoenix    454
# 8146      portland    373
# 5422     las vegas    367
# 5757   los angeles    352
# 8869     san diego    338
# 4598       houston    297
# 1779       chicago    264
# 10315       tucson    241
# 6346         miami    239
# 418         austin    218
# 7469       orlando    218
# 9630   springfield    214
# 86     albuquerque    213
# 8771    sacramento    201

# %%
# plot_pandas = ufo_city_count.plot.bar(color='blue')  
# plt.xlabel("City")
# plt.ylabel("Count")
# plt.title("How many times each city saw a UFO")
# plt.show()

# %%
ufo5=df_scrubbed_usa.groupby(["state"]).size().reset_index(name='count')
ufo_state_count = ufo5.sort_values(by='count', ascending=False)
ufo_state_count.head(50)
# Out:
#    state  count
# 4     ca   8912
# 48    wa   3966
# 9     fl   3835
# 44    tx   3447
# 34    ny   2980
# 14    il   2499
# 3     az   2414
# 38    pa   2366
# 35    oh   2275
# 22    mi   1836
# 37    or   1747
# 27    nc   1740
# 24    mo   1458
# 5     co   1413
# 15    in   1288
# 46    va   1273
# 19    ma   1256
# 31    nj   1255
# 10    ga   1255
# 49    wi   1232
# 43    tn   1119
# 23    mn   1012
# 41    sc   1003
# 6     ct    892
# 17    ky    855
# 20    md    837
# 33    nv    803
# 36    ok    724
# 32    nm    720
# 12    ia    678
# 1     al    642
# 45    ut    622
# 16    ks    613
# 2     ar    588
# 21    me    558
# 18    la    558
# 13    id    521
# 30    nh    486
# 26    mt    478
# 50    wv    448
# 29    ne    381
# 25    ms    375
# 0     ak    319
# 11    hi    262
# 47    vt    260
# 40    ri    228
# 42    sd    183
# 51    wy    175
# 8     de    166
# 28    nd    129

# %%
# plot_pandas = ufo_state_count.plot.bar(color='blue')  
# plt.xlabel("State")
# plt.ylabel("Count")
# plt.title("How many times each state saw a UFO")
# plt.show()

# %%
ufo6=df_scrubbed_usa.groupby(["country"]).size().reset_index(name='count')
ufo_country_count = ufo6.sort_values(by='count', ascending=False)
ufo_country_count.head(15)
# Out:
#   country  count
# 0      us  65114

# %% [markdown]
# # Final

# %%
# Export the data as a CSV so it has an ID column
# Rename the column to be consistent with SQL syntax for loading the data
df_scrubbed_usa = df_scrubbed_usa.rename(columns={"duration (seconds)":"duration_seconds", "date posted":"date_posted"})
display(df_scrubbed_usa.head(10))
df_scrubbed_usa.to_csv("final_data.csv", index=False)
# Out:
#     ID            datetime        city state country     shape  \
# 0    1 1949-10-10 20:30:00  san marcos    tx      us  cylinder
# 3    2 1956-10-10 21:00:00        edna    tx      us    circle
# 4    3 1960-10-10 20:00:00     kaneohe    hi      us     light
# 5    4 1961-10-10 19:00:00     bristol    tn      us    sphere
# 7    5 1965-10-10 23:45:00     norwalk    ct      us      disk
# 8    6 1966-10-10 20:00:00   pell city    al      us      disk
# 9    7 1966-10-10 21:00:00    live oak    fl      us      disk
# 10   8 1968-10-10 13:00:00   hawthorne    ca      us    circle
# 11   9 1968-10-10 19:00:00     brevard    nc      us  fireball
# 12  10 1970-10-10 16:00:00    bellmore    ny      us      disk
#
#     duration_seconds   latitude   longitude date_posted
# 0             2700.0  29.883056  -97.941111  2004-04-27
# 3               20.0  28.978333  -96.645833  2004-01-17
# 4              900.0  21.418056 -157.803611  2004-01-22
# 5              300.0  36.595000  -82.188889  2007-04-27
# 7             1200.0  41.117500  -73.408333  1999-10-02
# 8              180.0  33.586111  -86.286111  2009-03-19
# 9              120.0  30.294722  -82.984167  2005-05-11
# 10             300.0  33.916389 -118.351667  2003-10-31
# 11             180.0  35.233333  -82.734444  2008-06-12
# 12            1800.0  40.668611  -73.527500  2000-05-11

# %%
df_scrubbed_usa.dtypes
# Out:
# ID                           int64
# datetime            datetime64[ns]
# city                        object
# state                       object
# country                     object
# shape                       object
# duration_seconds           float64
# latitude                   float64
# longitude                  float64
# date_posted         datetime64[ns]
# dtype: object

# %%
duration_ufo=df_scrubbed_usa.groupby(["duration_seconds"]).size().reset_index(name='count')
duration_ufo
# Out:
#      duration_seconds  count
# 0                0.01      4
# 1                0.02      1
# 2                0.05      3
# 3                0.08      2
# 4                0.10      4
# ..                ...    ...
# 461        7894800.00      1
# 462        9468000.00      1
# 463       10526400.00      2
# 464       52623200.00      2
# 465       66276000.00      1
#
# [466 rows x 2 columns]

# %%
duration_ufo = df_scrubbed_usa['duration_seconds'].value_counts()
id_ufo = df_scrubbed_usa.groupby('duration_seconds')['ID'].count()

plt.scatter(id_ufo, duration_ufo,color="blue")
plt.xlabel('ID #')
plt.ylabel('Duration (sec)')
plt.title('How long each UFO was seen for')

plt.show()

# %%
#getting the average time each state saw the UFO for
summary_agg = df_scrubbed_usa.groupby(['state'])[['duration_seconds']].agg(['mean', 'median', 'var', 'std', 'sem'])
summary_agg
# Out:
#       duration_seconds
#                   mean median           var           std            sem
# state
# ak         4615.752351  300.0  1.735335e+09  4.165735e+04    2332.363978
# al         1411.538162  180.0  7.755986e+07  8.806807e+03     347.576967
# ar       113930.296769  180.0  7.470034e+12  2.733136e+06  112712.640611
# az         6422.913670  300.0  2.102015e+10  1.449833e+05    2950.864304
# ca         3380.859792  180.0  1.543658e+10  1.242440e+05    1316.097248
# co         3087.327035  120.0  4.332015e+09  6.581804e+04    1750.950545
# ct        14132.476233  180.0  1.045203e+11  3.232960e+05   10824.750230
# dc          235.071429   10.0  1.329620e+05  3.646396e+02     137.820813
# de          882.948795  270.0  4.032984e+06  2.008229e+03     155.868795
# fl        14593.241199  180.0  7.220866e+11  8.497568e+05   13721.827923
# ga         7600.329163  180.0  4.978828e+10  2.231329e+05    6298.566045
# hi        25708.198473  240.0  1.521060e+11  3.900077e+05   24094.756239
# ia          936.699115  180.0  1.581698e+07  3.977056e+03     152.737921
# id          929.029367  180.0  6.595249e+06  2.568122e+03     112.511456
# il          883.122877  180.0  3.313129e+07  5.755978e+03     115.142595
# in         3272.908929  180.0  5.421939e+09  7.363382e+04    2051.726072
# ks         1393.358075  180.0  1.596446e+08  1.263506e+04     510.325111
# ky         4040.173684  240.0  8.100102e+09  9.000057e+04    3077.954506
# la        12254.166667  180.0  7.138586e+10  2.671813e+05   11310.687535
# ma         1282.606688  120.0  7.065661e+07  8.405749e+03     237.181918
# md          834.966906  180.0  4.759313e+06  2.181585e+03      75.406610
# me         3357.985484  300.0  2.647488e+09  5.145375e+04    2178.210955
# mi         3923.128050  180.0  1.512885e+10  1.229994e+05    2870.560298
# mn         1382.596176  180.0  4.980556e+07  7.057305e+03     221.844495
# mo         1142.996433  180.0  3.966704e+07  6.298177e+03     164.943843
# ms         9064.805333  240.0  1.893845e+10  1.376170e+05    7106.513340
# mt         2231.615063  240.0  3.920870e+08  1.980119e+04     905.685170
# nc         1186.240431  180.0  1.216798e+08  1.103086e+04     264.444579
# nd         1105.147287  240.0  8.499977e+06  2.915472e+03     256.692997
# ne         1096.501312  180.0  2.358533e+07  4.856473e+03     248.804668
# nh         2228.021605  180.0  7.634393e+08  2.763041e+04    1253.340626
# nj         6226.090837  180.0  9.723712e+09  9.860888e+04    2783.518961
# nm         5699.346653  240.0  7.066066e+09  8.405989e+04    3132.727305
# nv         3013.286364  240.0  1.973531e+09  4.442444e+04    1567.704382
# ny         3003.656560  180.0  1.337749e+10  1.156611e+05    2118.747475
# oh         1453.723429  180.0  1.408959e+08  1.186996e+04     248.861903
# ok         1181.098481  180.0  4.926006e+07  7.018551e+03     260.842395
# or         1063.413440  180.0  2.709524e+07  5.205309e+03     124.537467
# pa         4120.428571  180.0  1.617953e+10  1.271988e+05    2615.023618
# pr         1050.400000   60.0  1.280663e+07  3.578635e+03     715.727036
# ri         2080.186404  180.0  1.866030e+08  1.366027e+04     904.673474
# sc         1104.023729  180.0  4.180191e+07  6.465440e+03     204.149171
# sd         2626.795082  180.0  6.550469e+08  2.559388e+04    1891.954387
# tn         1670.955585  180.0  3.920742e+08  1.980086e+04     591.928247
# tx         2463.959603  180.0  3.986709e+09  6.314039e+04    1075.441102
# ut         5500.345659  180.0  1.131715e+10  1.063821e+05    4265.534148
# va        10712.976434  180.0  9.047682e+10  3.007937e+05    8430.521952
# vt         1026.713462  180.0  5.282691e+07  7.268212e+03     450.755387
# wa        14470.397413  120.0  6.983888e+11  8.356966e+05   13270.041184
# wi         2041.445860  180.0  1.218969e+09  3.491374e+04     994.697499
# wv         6685.738839  180.0  1.545332e+10  1.243114e+05    5873.160205
# wy         1452.262857  120.0  5.021461e+07  7.086227e+03     535.668405

# %%
mean_state=df_scrubbed_usa['duration_seconds'].groupby(df_scrubbed_usa['state']).mean()

state_avg= mean_state.plot.bar(color='blue')
plt.xlabel('State')
plt.ylabel('Avg time (sec)')
plt.title('Average time per State')
plt.show()

# %%
#getting the average time each shape was seen 
summary_agg =  df_scrubbed_usa.groupby(['shape'])[['duration_seconds']].agg(['mean', 'median', 'var', 'std', 'sem'])
summary_agg
# Out:
#           duration_seconds
#                       mean   median           var            std          sem
# shape
# changed        3600.000000   3600.0           NaN            NaN          NaN
# changing       2149.946970    480.0  7.044557e+07    8393.185679   210.886725
# chevron         485.556994     60.0  2.078044e+06    1441.542331    50.495025
# cigar          2181.180463    180.0  2.071141e+09   45509.792420  1122.757779
# circle         3777.292285    180.0  1.687312e+10  129896.557341  1660.706574
# cone           1616.546559    300.0  2.435654e+07    4935.234242   314.021435
# crescent      37800.000000  37800.0           NaN            NaN          NaN
# cross           752.393617    240.0  2.119303e+06    1455.782559   106.173855
# cylinder       4131.035054    180.0  6.985745e+09   83580.771618  2608.081475
# delta          2682.500000    360.0  3.305308e+07    5749.180594  2347.093149
# diamond        1543.694504    300.0  6.391663e+07    7994.787816   262.441767
# disk           1474.505176    240.0  1.141569e+08   10684.423134   166.436959
# egg            2102.675731    180.0  2.850472e+08   16883.340894   700.439006
# fireball       4242.728153    120.0  3.014485e+10  173622.725633  2419.843618
# flare            30.000000     30.0           NaN            NaN          NaN
# flash          6468.329096     30.0  1.806472e+10  134405.056846  4124.329462
# formation      1010.118482    180.0  1.304602e+08   11421.915662   256.042707
# hexagon         240.000000    240.0           NaN            NaN          NaN
# light         15194.785959    180.0  7.414891e+11  861097.588076  7418.570323
# other          4056.668764    180.0  1.185702e+10  108889.929268  1629.402418
# oval           2255.203496    180.0  1.869942e+09   43242.822965   785.325029
# pyramid         120.000000    120.0           NaN            NaN          NaN
# rectangle       717.196729    180.0  1.069119e+07    3269.737988    99.958807
# round           452.500000    452.5  4.005125e+05     632.860569   447.500000
# sphere         1737.741189    180.0  6.476353e+08   25448.679845   385.985009
# teardrop        939.632601    120.0  5.532064e+07    7437.784693   305.691068
# triangle       1447.421929    180.0  1.161340e+09   34078.440579   421.106765
# unknown        6233.483884    180.0  3.431508e+10  185243.302849  2741.113446

# %%
mean_shape=df_scrubbed_usa['duration_seconds'].groupby(df_scrubbed_usa['shape']).mean()

shape_avg= mean_shape.plot.bar(color='blue')
plt.xlabel('Shape')
plt.ylabel('Avg time (sec)')
plt.title('Average time per Shape')
plt.show()

# %%
#work in progress. ignore for now
mean_shape_state=df_scrubbed_usa['shape'].groupby(df_scrubbed_usa['state']).count()

shape_avg= mean_shape_state.plot.bar(color='blue')
plt.xlabel('state')
plt.ylabel('Avg time (sec)')
plt.title('Average time per Shape')
plt.show()
